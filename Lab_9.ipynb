# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):

    distances = {}
    predecessors = {}
    visited = set()

    for node in graph:
        distances[node] = float('inf')
        predecessors[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        # If min_node is None, it means there are unreachable nodes
        if min_node is None:
            break

        visited.add(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                predecessors[neighbor] = min_node

    return distances, predecessors

def get_shortest_path(predecessors, start, target):
    path = []
    current = target
    while current is not None:
        path.insert(0, current)
        if current == start:
            break
        current = predecessors.get(current)

    if path and path[0] == start:
        return path
    return []

# %%
# Extended graph with two new nodes 'E' and 'F'
graph_extended = {
    'A': {'B': 4, 'C': 2},
    'B': {'A': 4, 'C': 5, 'D': 10, 'E': 3},
    'C': {'A': 2, 'B': 5, 'D': 3, 'F': 8},
    'D': {'B': 10, 'C': 3, 'E': 7, 'F': 6},
    'E': {'B': 3, 'D': 7, 'F': 1},
    'F': {'C': 8, 'D': 6, 'E': 1}
}


source_nodes_to_test = ['A', 'B', 'C', 'D', 'E', 'F']

for source in source_nodes_to_test:
    print(f"\n--- Shortest paths from source '{source}' ---")
    distances, predecessors = dijkstra(graph_extended, source)

    for target_node in graph_extended:
        if target_node == source:
            print(f"Distance from {source} to {target_node} = {distances[target_node]} (Path: {source})")
            continue

        path = get_shortest_path(predecessors, source, target_node)
        if distances[target_node] == float('inf'):
            print(f"Distance from {source} to {target_node} = Infinity (No path)")
        elif path:
            print(f"Distance from {source} to {target_node} = {distances[target_node]} (Path: {' -> '.join(path)})")
        else:
            print(f"Distance from {source} to {target_node} = {distances[target_node]} (Path: No path found)")
# Out:
# --- Shortest paths from source 'A' ---
# Distance from A to A = 0 (Path: A)
# Distance from A to B = 4 (Path: A -> B)
# Distance from A to C = 2 (Path: A -> C)
# Distance from A to D = 5 (Path: A -> C -> D)
# Distance from A to E = 7 (Path: A -> B -> E)
# Distance from A to F = 8 (Path: A -> B -> E -> F)
#
# --- Shortest paths from source 'B' ---
# Distance from B to A = 4 (Path: B -> A)
# Distance from B to B = 0 (Path: B)
# Distance from B to C = 5 (Path: B -> C)
# Distance from B to D = 8 (Path: B -> C -> D)
# Distance from B to E = 3 (Path: B -> E)
# Distance from B to F = 4 (Path: B -> E -> F)
#
# --- Shortest paths from source 'C' ---
# Distance from C to A = 2 (Path: C -> A)
# Distance from C to B = 5 (Path: C -> B)
# Distance from C to C = 0 (Path: C)
# Distance from C to D = 3 (Path: C -> D)
# Distance from C to E = 8 (Path: C -> B -> E)
# Distance from C to F = 8 (Path: C -> F)
#
# --- Shortest paths from source 'D' ---
# Distance from D to A = 5 (Path: D -> C -> A)
# Distance from D to B = 8 (Path: D -> C -> B)
# Distance from D to C = 3 (Path: D -> C)
# Distance from D to D = 0 (Path: D)
# Distance from D to E = 7 (Path: D -> E)
# Distance from D to F = 6 (Path: D -> F)
#
# --- Shortest paths from source 'E' ---
# Distance from E to A = 7 (Path: E -> B -> A)
# Distance from E to B = 3 (Path: E -> B)
# Distance from E to C = 8 (Path: E -> B -> C)
# Distance from E to D = 7 (Path: E -> D)
# Distance from E to E = 0 (Path: E)
# Distance from E to F = 1 (Path: E -> F)
#
# --- Shortest paths from source 'F' ---
# Distance from F to A = 8 (Path: F -> E -> B -> A)
# Distance from F to B = 4 (Path: F -> E -> B)
# Distance from F to C = 8 (Path: F -> C)
# Distance from F to D = 6 (Path: F -> D)
# Distance from F to E = 1 (Path: F -> E)
# Distance from F to F = 0 (Path: F)
