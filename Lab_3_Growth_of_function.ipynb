# %% [markdown]
# <a href="https://colab.research.google.com/github/241b139-arch/APS-lab-2/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
import matplotlib.pyplot as plt

#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )

def check_even_odd(number):
    # This function performs a fixed number of operations (modulo, comparison) regardless of the input 'number'
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    check_even_odd(n)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n (number magnitude)")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Even/Odd Check")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
import matplotlib.pyplot as plt

#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

def count_elements_greater_than_zero(arr):
    count = 0
    for x in arr:
        if x > 0:
            count += 1
    return count

n_values = list(range(1, 101))
time_values = []

for n in n_values:
  data = list(range(n))
  count_elements_greater_than_zero(data)
  time_values.append(n)

plt.figure()
plt.plot(n_values,time_values)
plt.xlabel("Input Size")
plt.ylabel("time")
plt.title("O(n) liner time complexity")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
import matplotlib.pyplot as plt
import math

#Prob_4 Take Suitable example and write function that runs in logarithmic time. plot graph as well similar to above example.

def binary_search(arr, target):
    low = 0
    high = len(arr) - 1
    steps = 0
    while low <= high:
        steps += 1
        mid = (low + high) // 2
        if arr[mid] == target:
            return steps
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1
    return steps

n_values = []
time_values = []

for n in range(1, 1001, 10):
    arr = list(range(n))
    target = n - 1
    if n > 0:
        steps = binary_search(arr, target)
        n_values.append(n)
        time_values.append(math.log2(n) + 1 if n > 1 else 1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (logarithmic scale)")
plt.title("O(log n) Logarithmic Time Complexity (Binary Search)")
plt.grid(True)
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
import matplotlib.pyplot as plt
import math
import time

#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]

    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)

    return merge(left_half, right_half)

def merge(left, right):
    merged = []
    left_idx, right_idx = 0, 0

    while left_idx < len(left) and right_idx < len(right):
        if left[left_idx] < right[right_idx]:
            merged.append(left[left_idx])
            left_idx += 1
        else:
            merged.append(right[right_idx])
            right_idx += 1

    merged.extend(left[left_idx:])
    merged.extend(right[right_idx:])
    return merged

n_values = []
time_values = []

for n in range(1, 1001, 10):
    data = list(range(n, 0, -1)) # Create a reversed list for worst-case sorting scenario

    if n > 1:
        time_complexity_value = n * math.log2(n)
    else:
        time_complexity_value = 0

    n_values.append(n)
    time_values.append(time_complexity_value)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n log n scale)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort Simulation)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
import matplotlib.pyplot as plt

# Prob_6 Take Suitable example and write function that runs in Polynomial time (e.g., O(n^2)).
# Plot the graph as well, similar to above examples.

def count_all_pairs(arr):
    count = 0
    for i in range(len(arr)):
        for j in range(len(arr)): # Nested loop creates O(n^2) operations
            count += 1
    return count

n_values = []
time_values = []

for n in range(1, 101, 1): # Increasing input size from 1 to 100
    data = list(range(n))
    count_all_pairs(data)
    # For O(n^2) complexity, time is proportional to n*n
    time_values.append(n**2)
    n_values.append(n)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (n^2 scale)")
plt.title("O(n^2) Polynomial Time Complexity (Counting All Pairs)")
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
import matplotlib.pyplot as plt
import time

# Prob_7 Take a suitable example and write a function that runs in exponential time. Plot the graph as well, similar to above example.
# A classic example is the naive recursive calculation of Fibonacci numbers.

def fibonacci_recursive(n):
    if n <= 1:
        return n
    else:
        return fibonacci_recursive(n-1) + fibonacci_recursive(n-2)

n_values = []
time_values = []
for n in range(1, 21): # For larger n, this becomes too slow to compute in practice
    start_time = time.perf_counter_ns()
    fibonacci_recursive(n)
    end_time = time.perf_counter_ns()

    n_values.append(n)
    time_values.append(end_time - start_time)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values, marker='o')
plt.xlabel("Input size n")
plt.ylabel("Time (nanoseconds)")
plt.title("O(2^n) Exponential Time Complexity (Naive Fibonacci)")
plt.grid(True)
plt.yscale('log') # Use a logarithmic scale for the y-axis to better visualize the rapid growth
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import math

# Prob_8: Plot a graph similar to the given figure, comparing all the discussed time complexities.

n_values = list(range(1, 101))

# O(1) Constant
time_o1 = [1 for _ in n_values]

# O(log n) Logarithmic
time_ologn = [math.log2(n) if n > 0 else 0 for n in n_values]

# O(n) Linear
time_on = n_values

# O(n log n) Log-Linear
time_onlogn = [n * math.log2(n) if n > 0 else 0 for n in n_values]

# O(n^2) Polynomial (Quadratic)
time_on2 = [n**2 for n in n_values]

n_values_comp = list(range(1, 11))

time_o1_comp = [1 for _ in n_values_comp]
time_ologn_comp = [math.log2(n) if n > 0 else 0 for n in n_values_comp]
time_on_comp = n_values_comp
time_onlogn_comp = [n * math.log2(n) if n > 0 else 0 for n in n_values_comp]
time_on2_comp = [n**2 for n in n_values_comp]
time_o2n_comp = [2**n for n in n_values_comp]

plt.figure(figsize=(12, 8))
plt.plot(n_values_comp, time_o1_comp, label='O(1) Constant', marker='o', linestyle='--')
plt.plot(n_values_comp, time_ologn_comp, label='O(log n) Logarithmic', marker='o', linestyle='--')
plt.plot(n_values_comp, time_on_comp, label='O(n) Linear', marker='o', linestyle='--')
plt.plot(n_values_comp, time_onlogn_comp, label='O(n log n) Log-Linear', marker='o', linestyle='--')
plt.plot(n_values_comp, time_on2_comp, label='O(n^2) Quadratic', marker='o', linestyle='--')
plt.plot(n_values_comp, time_o2n_comp, label='O(2^n) Exponential', marker='o', linestyle='--')

plt.xlabel("Input Size (n)")
plt.ylabel("Relative Operations / Time")
plt.title("Comparison of Time Complexities")
plt.legend()
plt.grid(True)
plt.yscale('log') # Logarithmic scale for y-axis to see differences across wide range of values
plt.xticks(n_values_comp) # Ensure x-axis ticks are clear
plt.show()

# %%
import matplotlib.pyplot as plt
import time
import random

# Assuming quick_sort function is already defined in the notebook
# from previous cell '7PnONFDTIoWC'

n_values = []
time_values = []

for n in range(1, 1001, 50): # Step by 50 to keep computation reasonable
    # Generate a random list of n elements for sorting
    data = [random.randint(0, 10000) for _ in range(n)]

    start_time = time.perf_counter_ns()
    quick_sort(data.copy()) # Use .copy() to ensure original data isn't modified
    end_time = time.perf_counter_ns()

    n_values.append(n)
    time_values.append(end_time - start_time)

plt.figure(figsize=(10, 6))
plt.plot(n_values, time_values, marker='o', linestyle='-')
plt.xlabel("Input size n")
plt.ylabel("Time (nanoseconds)")
plt.title("Quick Sort Time Complexity (Average Case Simulation)")
plt.grid(True)
plt.show()
